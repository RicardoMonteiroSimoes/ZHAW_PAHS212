# %%
import numpy as np
import matplotlib.pyplot as plt

#create folder for figures
import os
path_non_r = 'finished/figures/AP/non_randomized_split/'
path_r = 'finished/figures/AP/randomized_split/'
try:
    os.makedirs(path_non_r)
except:
    print('path already exists!')
try:
    os.makedirs(path_r)
except:
    print('path already exists!')
# Out:
# path already exists!
# path already exists!

# %%
def plot_boxplots(path, run, title, circuit_index, save=False):
    min = np.amin(run)-0.01
    max = np.amax(run)+0.01
    fig = plt.figure()
    gs = fig.add_gridspec(1, 2, hspace=0, wspace=0)
    (ax1, ax2) = gs.subplots(sharex='col', sharey='row')
    ax1.set_ylim([min,max])
    ax2.set_ylim([min,max])
    fig.suptitle(title)
    ax1.set_title('Training')
    ax1.boxplot(run[0], showfliers=True, sym='k.')
    ax2.set_title('Testing')
    ax2.boxplot(run[1], showfliers=True, sym='k.')
    if(save):
        plt.savefig(path+title.replace(" ", "_")+'.svg', format="svg", transparent=True)
    else:
        plt.show()
    plt.close()

# %%
AP_measured_pure = [[
  [0.5240641711229946, 0.47593582887700536, 0.5561497326203209, 0.5294117647058824, 0.5080213903743316, 0.5026737967914439, 0.5026737967914439, 0.5187165775401069, 0.5454545454545454, 0.5240641711229946],
  [0.49206349206349204, 0.5396825396825397, 0.5079365079365079, 0.42857142857142855, 0.47619047619047616, 0.4444444444444444, 0.47619047619047616, 0.47619047619047616, 0.47619047619047616, 0.42857142857142855]
  ],
 [[0.5347593582887701, 0.5294117647058824, 0.5508021390374331, 0.5454545454545454, 0.5347593582887701, 0.48663101604278075, 0.49732620320855614, 0.5080213903743316, 0.5080213903743316, 0.5347593582887701], [0.5396825396825397, 0.49206349206349204, 0.47619047619047616, 0.49206349206349204, 0.4603174603174603, 0.5238095238095238, 0.4603174603174603, 0.47619047619047616, 0.4603174603174603, 0.47619047619047616]],
 [[0.5240641711229946, 0.5080213903743316, 0.5026737967914439, 0.5294117647058824, 0.5294117647058824, 0.5133689839572193, 0.5080213903743316, 0.49732620320855614, 0.5294117647058824, 0.49732620320855614], [0.4603174603174603, 0.5238095238095238, 0.5079365079365079, 0.5396825396825397, 0.5079365079365079, 0.4444444444444444, 0.5238095238095238, 0.49206349206349204, 0.49206349206349204, 0.4444444444444444]],
 [[0.49732620320855614, 0.5187165775401069, 0.5347593582887701, 0.5508021390374331, 0.5080213903743316, 0.5187165775401069, 0.5401069518716578, 0.5080213903743316, 0.5240641711229946, 0.5133689839572193], [0.47619047619047616, 0.47619047619047616, 0.4603174603174603, 0.47619047619047616, 0.4444444444444444, 0.47619047619047616, 0.5079365079365079, 0.47619047619047616, 0.4444444444444444, 0.49206349206349204]],
 [[0.49732620320855614, 0.5187165775401069, 0.5026737967914439, 0.5294117647058824, 0.5026737967914439, 0.5133689839572193, 0.5080213903743316, 0.5187165775401069, 0.5080213903743316, 0.5187165775401069], [0.49206349206349204, 0.4603174603174603, 0.47619047619047616, 0.5714285714285714, 0.49206349206349204, 0.47619047619047616, 0.47619047619047616, 0.49206349206349204, 0.47619047619047616, 0.5079365079365079]],
 [[0.5828877005347594, 0.5721925133689839, 0.5187165775401069, 0.5508021390374331, 0.5080213903743316, 0.5401069518716578, 0.5614973262032086, 0.5508021390374331, 0.5828877005347594, 0.5882352941176471], [0.49206349206349204, 0.49206349206349204, 0.4126984126984127, 0.4444444444444444, 0.4603174603174603, 0.42857142857142855, 0.4603174603174603, 0.4444444444444444, 0.42857142857142855, 0.42857142857142855]],
 [[0.5240641711229946, 0.5294117647058824, 0.5294117647058824, 0.5347593582887701, 0.5721925133689839, 0.5080213903743316, 0.5401069518716578, 0.49732620320855614, 0.47593582887700536, 0.5240641711229946], [0.47619047619047616, 0.47619047619047616, 0.4126984126984127, 0.4126984126984127, 0.4126984126984127, 0.47619047619047616, 0.4444444444444444, 0.4126984126984127, 0.4126984126984127, 0.47619047619047616]],
 [[0.5401069518716578, 0.5614973262032086, 0.5668449197860963, 0.5561497326203209, 0.5508021390374331, 0.5561497326203209, 0.5454545454545454, 0.5454545454545454, 0.5401069518716578, 0.5614973262032086], [0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603, 0.4603174603174603]]]

# %%
def comparison_all_circuits(measurments,title, path, save=False):
    tests = []
    for run in measurments:
        tests.append(run[1])
    min = np.amin(tests)-0.01
    max = np.amax(tests)+0.01
    fig = plt.figure()
    gs = fig.add_gridspec(1, 1, hspace=0, wspace=0)
    (ax1) = gs.subplots(sharex='col', sharey='row')
    ax1.set_ylim([min,max])
    fig.suptitle(title)
    ax1.set_title('Testing')
    ax1.boxplot(tests, showfliers=True, sym='k.')
    if(save):
        plt.savefig(path+title.replace(" ", "_")+'.svg', format="svg", transparent=True)
    else:
        plt.show()
    plt.close()

# %%
for index, run in enumerate(AP_measured_pure):
    title = "Raw data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_non_r, run, title, index+1, save=False)

# %%
comparison_all_circuits(AP_measured_pure, "Comparison of all circuits with non randomized, raw data", path_non_r)

# %%
for index, run in enumerate(AP_measured_normalized):
    title = "Normalized data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_non_r, run, title, index+1, save=False)

# %%
comparison_all_circuits(AP_measured_normalized, "Comparison of all circuits with non randomized, normalized data", path_non_r)

# %%
for index, run in enumerate(AP_measured_pified):
    title = "Pified data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_non_r, run, title, index+1, save=False)

# %%
comparison_all_circuits(AP_measured_pified, "Comparison of all circuits with non randomized, pified data", path_non_r)

# %%
for index, run in enumerate(AP_measured_pure_r):
    title = "Raw data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_r, run, title, index+1, save=False)

# %%
comparison_all_circuits(AP_measured_pure_r, "Comparison of all circuits with randomized, raw data", path_r)

# %%
for index, run in enumerate(AP_measured_normalized_r):
    title = "Normalized data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_r, run, title, index+1, save=False)

# %%
comparison_all_circuits(AP_measured_normalized_r, "Comparison of all circuits with randomized, normalized data", path_r)

# %%
for index, run in enumerate(AP_measured_pified_r):
    title = "Pified data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_r, run, title, index+1, save=False)

# %%
comparison_all_circuits(AP_measured_pified_r, "Comparison of all circuits with randomized, pified data", path_r)
