# %%
import numpy as np
import matplotlib.pyplot as plt

#create folder for figures
import os
path_non_r = 'finished/figures/HF/non_randomized_split/'
path_r = 'finished/figures/HF/randomized_split/'
try:
    os.makedirs(path_non_r)
except:
    print('path already exists!')
try:
    os.makedirs(path_r)
except:
    print('path already exists!')

# %%
def plot_boxplots(path, run, title, circuit_index, save=False):
    min = np.amin(run)-0.01
    max = np.amax(run)+0.01
    fig = plt.figure()
    gs = fig.add_gridspec(1, 2, hspace=0, wspace=0)
    (ax1, ax2) = gs.subplots(sharex='col', sharey='row')
    ax1.set_ylim([min,max])
    ax2.set_ylim([min,max])
    fig.suptitle(title)
    ax1.set_title('Training')
    ax1.boxplot(run[0], showfliers=True, sym='k.')
    ax2.set_title('Testing')
    ax2.boxplot(run[1], showfliers=True, sym='k.')
    if(save):
        plt.savefig(path+title.replace(" ", "_")+'.svg', format="svg", transparent=True)
    plt.close()

# %%
hf_measured_pure = [[[0.6205357142857143, 0.53125, 0.6071428571428571, 0.6383928571428571, 0.6383928571428571, 0.6383928571428571, 0.6517857142857143, 0.6517857142857143, 0.6517857142857143, 0.6383928571428571], [0.49333333333333335, 0.5466666666666666, 0.5733333333333334, 0.49333333333333335, 0.48, 0.49333333333333335, 0.5066666666666667, 0.49333333333333335, 0.5066666666666667, 0.48]], [[0.6294642857142857, 0.5491071428571429, 0.6517857142857143, 0.6428571428571429, 0.6428571428571429, 0.6294642857142857, 0.65625, 0.59375, 0.65625, 0.6071428571428571], [0.49333333333333335, 0.6133333333333333, 0.5066666666666667, 0.5066666666666667, 0.49333333333333335, 0.48, 0.52, 0.5333333333333333, 0.52, 0.5466666666666666]], [[0.5580357142857143, 0.5401785714285714, 0.5267857142857143, 0.5223214285714286, 0.48214285714285715, 0.5401785714285714, 0.5491071428571429, 0.5580357142857143, 0.5446428571428571, 0.5982142857142857], [0.5733333333333334, 0.5466666666666666, 0.6, 0.5333333333333333, 0.5066666666666667, 0.5466666666666666, 0.5066666666666667, 0.6266666666666667, 0.56, 0.52]], [[0.7008928571428571, 0.7098214285714286, 0.7276785714285714, 0.6696428571428571, 0.65625, 0.7142857142857143, 0.6160714285714286, 0.6875, 0.6428571428571429, 0.6919642857142857], [0.76, 0.6666666666666666, 0.76, 0.5733333333333334, 0.52, 0.76, 0.5066666666666667, 0.7466666666666667, 0.5066666666666667, 0.5733333333333334]], [[0.71875, 0.6428571428571429, 0.6517857142857143, 0.6383928571428571, 0.7276785714285714, 0.6428571428571429, 0.6428571428571429, 0.6428571428571429, 0.6517857142857143, 0.6383928571428571], [0.6933333333333334, 0.48, 0.48, 0.49333333333333335, 0.6666666666666666, 0.48, 0.48, 0.48, 0.5066666666666667, 0.5066666666666667]], [[0.6294642857142857, 0.65625, 0.6383928571428571, 0.625, 0.6383928571428571, 0.6294642857142857, 0.6473214285714286, 0.65625, 0.6205357142
64]], [[0.7321428571428571, 0.7410714285714286, 0.6785714285714286, 0.7589285714285714, 0.7366071428571429, 0.7276785714285714, 0.6964285714285714, 0.7767857142857143, 0.7544642857142857, 0.6964285714285714], [0.6533333333333333, 0.8, 0.64, 0.6666666666666666, 0.76, 0.6266666666666667, 0.7333333333333333, 0.72, 0.64, 0.6666666666666666]], [[0.7232142857142857, 0.6741071428571429, 0.7053571428571429, 0.7142857142857143, 0.7008928571428571, 0.7098214285714286, 0.7098214285714286, 0.6741071428571429, 0.7098214285714286, 0.7008928571428571], [0.5866666666666667, 0.7333333333333333, 0.64, 0.6133333333333333, 0.64, 0.6266666666666667, 0.6533333333333333, 0.76, 0.6533333333333333, 0.64]], [[0.7276785714285714, 0.6875, 0.6964285714285714, 0.7142857142857143, 0.71875, 0.7232142857142857, 0.6964285714285714, 0.7053571428571429, 0.7276785714285714, 0.6875], [0.64, 0.7333333333333333, 0.7333333333333333, 0.6133333333333333, 0.7333333333333333, 0.6266666666666667, 0.7466666666666667, 0.7333333333333333, 0.6933333333333334, 0.7333333333333333]], [[0.6294642857142857, 0.6339285714285714, 0.6473214285714286, 0.6116071428571429, 0.6339285714285714, 0.6071428571428571, 0.5982142857142857, 0.6160714285714286, 0.625, 0.5982142857142857], [0.64, 0.56, 0.5333333333333333, 0.6266666666666667, 0.5866666666666667, 0.6133333333333333, 0.6, 0.6, 0.6133333333333333, 0.6533333333333333]]]

# %%
def comparison_all_circuits(measurments,title, path, save=True):
    tests = []
    for run in measurments:
        tests.append(run[1])
    min = np.amin(tests)-0.01
    max = np.amax(tests)+0.01
    fig = plt.figure()
    gs = fig.add_gridspec(1, 1, hspace=0, wspace=0)
    (ax1) = gs.subplots(sharex='col', sharey='row')
    ax1.set_ylim([min,max])
    fig.suptitle(title)
    ax1.set_title('Testing')
    ax1.boxplot(tests, showfliers=True, sym='k.')
    if(save):
        plt.savefig(path+title.replace(" ", "_")+'.svg', format="svg", transparent=True)
    plt.close()

# %%
for index, run in enumerate(hf_measured_pure):
    title = "Raw data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_non_r, run, title, index+1, save=True)

# %%
comparison_all_circuits(hf_measured_pure, "Comparison of all circuits with non randomized, raw data", path_non_r)

# %%
for index, run in enumerate(hf_measured_normalized):
    title = "Normalized data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_non_r, run, title, index+1, save=True)

# %%
comparison_all_circuits(hf_measured_normalized, "Comparison of all circuits with non randomized, normalized data", path_non_r)

# %%
for index, run in enumerate(hf_measured_pified):
    title = "Pified data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_non_r, run, title, index+1, save=True)

# %%
comparison_all_circuits(hf_measured_pified, "Comparison of all circuits with non randomized, pified data", path_non_r)

# %%
for index, run in enumerate(hf_measured_pure_r):
    title = "Raw data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_r, run, title, index+1, save=True)

# %%
comparison_all_circuits(hf_measured_pure_r, "Comparison of all circuits with randomized, raw data", path_r)

# %%
for index, run in enumerate(hf_measured_normalized_r):
    title = "Normalized data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_r, run, title, index+1, save=True)

# %%
comparison_all_circuits(hf_measured_normalized_r, "Comparison of all circuits with randomized, normalized data", path_r)

# %%
for index, run in enumerate(hf_measured_pified_r):
    title = "Pified data with 10 iterations for circuit " + str(index+1)
    plot_boxplots(path_r, run, title, index+1, save=True)

# %%
comparison_all_circuits(hf_measured_pified_r, "Comparison of all circuits with randomized, pified data", path_r)
